# %% [markdown]
# # Potential Online Programming Advertising Markets
#
# ## Project Goals:
#
# Find out markets would be best to advertise in for a new subscription service that offers Web and Mobile Development courses.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Reading in the data
code_surveys = pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv", low_memory=False)

# %%
# Previewing the data
code_surveys.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls         ...           \
# 0                   NaN                   NaN         ...
# 1                   NaN                   NaN         ...
# 2                   NaN                   NaN         ...
# 3                   NaN                   NaN         ...
# 4                   NaN                   NaN         ...
#
#    YouTubeFCC  YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0         NaN                    NaN               NaN               NaN
# 1         1.0                    NaN               NaN               NaN
# 2         NaN                    NaN               NaN               1.0
# 3         1.0                    1.0               NaN               NaN
# 4         NaN                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %%
print("The shape of the data is:\n{}".format(code_surveys.shape))
print("The column names are:\n{}".format(code_surveys.columns))
# Out:
# The shape of the data is:
# (18175, 136)
# The column names are:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampLoanYesNo',
#        'BootcampName', 'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventConferences', 'CodeEventDjangoGirls',
#        ...
#        'YouTubeFCC', 'YouTubeFunFunFunction', 'YouTubeGoogleDev',
#        'YouTubeLearnCode', 'YouTubeLevelUpTuts', 'YouTubeMIT',
#        'YouTubeMozillaHacks', 'YouTubeOther', 'YouTubeSimplilearn',
#        'YouTubeTheNewBoston'],
#       dtype='object', length=136)

# %%
code_surveys.describe()
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# count  15367.000000      17709.000000     1069.000000        1079.000000
# mean      27.691872          0.062002        0.699719           0.305839
# std        8.559239          0.241167        0.458594           0.460975
# min        0.000000          0.000000        0.000000           0.000000
# 25%       22.000000          0.000000        0.000000           0.000000
# 50%       26.000000          0.000000        1.000000           0.000000
# 75%       32.000000          0.000000        1.000000           1.000000
# max       90.000000          1.000000        1.000000           1.000000
#
#        BootcampRecommend  ChildrenNumber  CodeEventConferences  \
# count        1073.000000     2314.000000                1609.0
# mean            0.818267        1.832325                   1.0
# std             0.385805        0.972813                   0.0
# min             0.000000        1.000000                   1.0
# 25%             1.000000        1.000000                   1.0
# 50%             1.000000        2.000000                   1.0
# 75%             1.000000        2.000000                   1.0
# max             1.000000        9.000000                   1.0
#
#        CodeEventDjangoGirls  CodeEventFCC  CodeEventGameJam  \
# count                 165.0        1708.0             290.0
# mean                    1.0           1.0               1.0
# std                     0.0           0.0               0.0
# min                     1.0           1.0               1.0
# 25%                     1.0           1.0               1.0
# 50%                     1.0           1.0               1.0
# 75%                     1.0           1.0               1.0
# max                     1.0           1.0               1.0
#
#               ...           YouTubeEngineeredTruth  YouTubeFCC  \
# count         ...                            993.0      6036.0
# mean          ...                              1.0         1.0
# std           ...                              0.0         0.0
# min           ...                              1.0         1.0
# 25%           ...                              1.0         1.0
# 50%           ...                              1.0         1.0
# 75%           ...                              1.0         1.0
# max           ...                              1.0         1.0
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# count                 1261.0            3539.0            2662.0
# mean                     1.0               1.0               1.0
# std                      0.0               0.0               0.0
# min                      1.0               1.0               1.0
# 25%                      1.0               1.0               1.0
# 50%                      1.0               1.0               1.0
# 75%                      1.0               1.0               1.0
# max                      1.0               1.0               1.0
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  \
# count              1396.0      3327.0                622.0
# mean                  1.0         1.0                  1.0
# std                   0.0         0.0                  0.0
# min                   1.0         1.0                  1.0
# 25%                   1.0         1.0                  1.0
# 50%                   1.0         1.0                  1.0
# 75%                   1.0         1.0                  1.0
# max                   1.0         1.0                  1.0
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# count               201.0               2960.0
# mean                  1.0                  1.0
# std                   0.0                  0.0
# min                   1.0                  1.0
# 25%                   1.0                  1.0
# 50%                   1.0                  1.0
# 75%                   1.0                  1.0
# max                   1.0                  1.0
#
# [8 rows x 105 columns]

# %% [markdown]
# ## Data Relevance
# For the purpose of our analysis, we want to answer questions about a population of new coders that are interested in the subjects we teach. We'd like to know:
#
# - Where are these new coders located.
# - What are the locations with the greatest number of new coders.
# - How much money new coders are willing to spend on learning.

# %%
# Subsetting the job information
job_interests = code_surveys['JobRoleInterest']

# %% [markdown]
# Since the JobRoleInterest column can contain multiple answers the data will be separated using the split() function over the common and appended to a new list for analysis.

# %%
# Create an empty list to hold the separated job functions
jobs = []

# Loop through each iten in job_interest
for job in job_interests:
    # Check to see if it is of type string
    if type(job) is str:
        # Split the string and add the item to the list
        for item in job.split(","):
            jobs.append(item)
    # If it is not a string, ex. NaN, then just add
    else:
        jobs.append(job)

# %%
# Uses the Counter function to count
# the appearance of each item and create a dictionary
job_series = pd.Series(jobs).value_counts().sort_values(ascending=False).reset_index()
job_series
# Out:
#                                               index     0
# 0                          Full-Stack Web Developer  2490
# 1                           Front-End Web Developer  2287
# 2                            Back-End Web Developer  1997
# 3                                  Mobile Developer  1734
# 4                          Full-Stack Web Developer  1708
# 5                           Front-End Web Developer  1246
# 6                                    Game Developer  1162
# 7                                    Data Scientist  1120
# 8                          User Experience Designer  1078
# 9                              Information Security   986
# 10                                    Data Engineer   944
# 11                           Back-End Web Developer   775
# 12                                DevOps / SysAdmin   695
# 13                                  Product Manager   600
# 14                                 Mobile Developer   570
# 15                                   Data Scientist   523
# 16                                   Game Developer   466
# 17                         User Experience Designer   391
# 18                       Quality Assurance Engineer   389
# 19                             Information Security   340
# 20                                    Data Engineer   304
# 21                                DevOps / SysAdmin   232
# 22                                  Product Manager   214
# 23                       Quality Assurance Engineer   109
# 24                                Software Engineer     6
# 25                                Software Engineer     5
# 26                               Software Developer     4
# 27                    Desktop Application Developer     3
# 28                                       Programmer     2
# 29                                        undecided     2
# ..                                              ...   ...
# 206                Artificial Intelligence engineer     1
# 207   Software Developer or Front-End Web Developer     1
# 208                               College professor     1
# 209                                        back-end     1
# 210                                 System Software     1
# 211                                  Bitcoin/Crypto     1
# 212                         User Interface Designer     1
# 213                 Desktop Applications Programmer     1
# 214                   Data Visualization Specialist     1
# 215                                        back end     1
# 216                                   IoT Developer     1
# 217                         Bioinformatics/science      1
# 218                                   Informatician     1
# 219                            Software Engineering     1
# 220           Journalist/Graphic Designer/Marketing     1
# 221                               Real-time systems     1
# 222                                   Urban Planner     1
# 223                                   Growth Hacker     1
# 224                             Digital Humanitites     1
# 225                                Python Developer     1
# 226                                    Any of them.     1
# 227                data journalist / data visualist     1
# 228                                         Founder     1
# 229                           Information Architect     1
# 230                                             plc     1
# 231     creative coder / generative artist/designer     1
# 232                                        Not Sure     1
# 233                              Embedded Developer     1
# 234                           Full Stack Developer      1
# 235                                   lab scientist     1
#
# [236 rows x 2 columns]

# %%
# The job titles that have to deal with the web
web = job_series[job_series['index'].str.contains('Web')]
web
# Out:
#                                               index     0
# 0                          Full-Stack Web Developer  2490
# 1                           Front-End Web Developer  2287
# 2                            Back-End Web Developer  1997
# 4                          Full-Stack Web Developer  1708
# 5                           Front-End Web Developer  1246
# 11                           Back-End Web Developer   775
# 70                                    Web developer     1
# 89                                 Web development      1
# 97                  Entreprenuer / Web Dev Hustler      1
# 115                                    Web Designer     1
# 130                                    Web Designer     1
# 138                       Front End Web Development     1
# 146                                      Web Design     1
# 194                          Front-End Web Designer     1
# 207   Software Developer or Front-End Web Developer     1

# %%
# The job titles that have to deal with the mobile
mobile = job_series[job_series['index'].str.contains('Mobile')]
mobile
# Out:
#                    index     0
# 3       Mobile Developer  1734
# 14      Mobile Developer   570
# 106   Mobile Development     1

# %% [markdown]
# Web Development and Mobile Development were the top 6 mentioned job interests in the frequency table.

# %%
# Subsetting the data to include those who marked interest in Web or Development
interested_coders = code_surveys[code_surveys["JobRoleInterest"].str.contains("Web|Mobile") == True].copy()

# %%
countries_rel = interested_coders['CountryLive'].value_counts(normalize=True)
countries_abs = interested_coders['CountryLive'].value_counts()

pd.DataFrame(data={'Relative Frequency': countries_rel, 'Absolute Frequency': countries_abs})
# Out:
#                                Absolute Frequency  Relative Frequency
# United States of America                     2677            0.453268
# India                                         443            0.075008
# United Kingdom                                281            0.047579
# Canada                                        221            0.037420
# Poland                                        121            0.020488
# Brazil                                        115            0.019472
# Germany                                       107            0.018117
# Russia                                         94            0.015916
# Australia                                      88            0.014900
# Ukraine                                        86            0.014561
# Nigeria                                        75            0.012699
# France                                         67            0.011344
# Spain                                          63            0.010667
# Romania                                        61            0.010328
# Italy                                          53            0.008974
# Netherlands (Holland, Europe)                  53            0.008974
# Serbia                                         52            0.008805
# Philippines                                    47            0.007958
# Greece                                         37            0.006265
# Ireland                                        37            0.006265
# Mexico                                         33            0.005588
# South Africa                                   32            0.005418
# Hungary                                        31            0.005249
# Croatia                                        31            0.005249
# Turkey                                         29            0.004910
# New Zealand                                    29            0.004910
# Pakistan                                       29            0.004910
# Sweden                                         29            0.004910
# Singapore                                      29            0.004910
# Norway                                         28            0.004741
# ...                                           ...                 ...
# Cameroon                                        1            0.000169
# Ecuador                                         1            0.000169
# Kyrgyzstan                                      1            0.000169
# Bolivia                                         1            0.000169
# Somalia                                         1            0.000169
# Bahrain                                         1            0.000169
# Gibraltar                                       1            0.000169
# Mozambique                                      1            0.000169
# Cayman Islands                                  1            0.000169
# Guatemala                                       1            0.000169
# Panama                                          1            0.000169
# Botswana                                        1            0.000169
# Vanuatu                                         1            0.000169
# Yemen                                           1            0.000169
# Liberia                                         1            0.000169
# Gambia                                          1            0.000169
# Nambia                                          1            0.000169
# Channel Islands                                 1            0.000169
# Nicaragua                                       1            0.000169
# Papua New Guinea                                1            0.000169
# Moldova                                         1            0.000169
# Aruba                                           1            0.000169
# Anguilla                                        1            0.000169
# Samoa                                           1            0.000169
# Trinidad & Tobago                               1            0.000169
# Guadeloupe                                      1            0.000169
# Sudan                                           1            0.000169
# Myanmar                                         1            0.000169
# Turkmenistan                                    1            0.000169
# Qatar                                           1            0.000169
#
# [135 rows x 2 columns]

# %%
% matplotlib inline
plt.style.use("fivethirtyeight")
countries.head().plot.bar()
plt.ylabel("Percentage \%")
plt.xlabel("Country")
plt.title("Top 5 Countries")

# %% [markdown]
# Participation of the survey, from individiduals are interested in mobile or web development, is approximately 45% from people who live in the United States of America, with about 7% from India.  As FreeCodeCamp courses are in English, and four out of the top 5 countries have English as a primary language, these would be a good place to start advertising in.

# %%
# Subsetting data to only look at the top 4 countries
interested_countries = interested_coders[interested_coders['CountryLive'].isin(countries.head(4).index)].copy()

# %%
print("The shape of the df:{}".format(interested_countries.shape))
# Replacing zero values in the MonthsProgramming column
interested_countries["MonthsProgramming"] = interested_countries["MonthsProgramming"].replace(0,1)
# Adding a column to calculate the money spent
interested_countries["MoneyPerMonth"] = interested_countries["MoneyForLearning"]/interested_countries["MonthsProgramming"]
print("The number people who haven't spent money:{}".format(sum(interested_countries["MoneyPerMonth"].isna())))
# Out:
# The shape of the df:(3622, 136)
# The number people who haven't spent money:262

# %%
# Drop Null values
interested_countries.dropna(subset=["MoneyPerMonth"], inplace=True)
# Checking that null values were dropped
print("The number people who haven't spent money:{}".format(sum(interested_countries["MoneyPerMonth"].isna())))
# Out:
# The number people who haven't spent money:0

# %%
money_country = interested_countries.groupby('CountryLive').mean()
money_country['MoneyPerMonth'][['United States of America',
                            'India', 'United Kingdom',
                            'Canada']]
# Out:
# CountryLive
# United States of America    249.428152
# India                       146.663700
# United Kingdom               49.117435
# Canada                      129.170946
# Name: MoneyPerMonth, dtype: float64

# %%
# Isolating the top 4 countries
top_4 = interested_countries[interested_countries['CountryLive'].str.contains(
'United States of America|India|United Kingdom|Canada')]

# %%
import seaborn as sns
# Generating a box plot for each country for how much money is spent
sns.boxplot(y='MoneyPerMonth', x='CountryLive', data=top_4)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
         fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %% [markdown]
# Based on the boxplots it looks like there are some large outliers for the US and India that may need to be removed. The outliers for the US will be removed first to get a better look at India.  It is highly improbable that individuals spent more than $20,000/month on non-tuition related courses.

# %%
# Removing extreme outliers
top_4 = top_4[top_4['MoneyPerMonth']<20000]

# %%
# Generating a box plot for each country for how much money is spent
sns.boxplot(y='MoneyPerMonth', x='CountryLive', data=top_4)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
         fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
# Looking at the top values in India
india_outliers = top_4[(top_4['CountryLive']=='India')&(top_4['MoneyPerMonth']>2000)]
india_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1728   24.0               0.0             NaN                NaN          NaN
# 1755   20.0               0.0             NaN                NaN          NaN
# 7989   28.0               0.0             NaN                NaN          NaN
# 8126   22.0               0.0             NaN                NaN          NaN
# 13398  19.0               0.0             NaN                NaN          NaN
# 15587  27.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1728                 NaN             NaN  between 100,000 and 1 million
# 1755                 NaN             NaN            more than 1 million
# 7989                 NaN             NaN  between 100,000 and 1 million
# 8126                 NaN             NaN            more than 1 million
# 13398                NaN             NaN            more than 1 million
# 15587                NaN             NaN            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls      ...        \
# 1728                    NaN                   NaN      ...
# 1755                    NaN                   NaN      ...
# 7989                    1.0                   NaN      ...
# 8126                    NaN                   NaN      ...
# 13398                   NaN                   NaN      ...
# 15587                   NaN                   NaN      ...
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 1728                     NaN               NaN               NaN
# 1755                     NaN               NaN               1.0
# 7989                     NaN               NaN               NaN
# 8126                     NaN               1.0               NaN
# 13398                    NaN               NaN               NaN
# 15587                    NaN               1.0               1.0
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  YouTubeOther  \
# 1728                  NaN         NaN                  NaN           NaN
# 1755                  NaN         1.0                  NaN           NaN
# 7989                  NaN         NaN                  NaN           NaN
# 8126                  NaN         1.0                  NaN           NaN
# 13398                 NaN         NaN                  NaN           NaN
# 15587                 NaN         1.0                  NaN           NaN
#
#       YouTubeSimplilearn  YouTubeTheNewBoston  MoneyPerMonth
# 1728                 NaN                  NaN    5000.000000
# 1755                 NaN                  NaN    3333.333333
# 7989                 NaN                  NaN    5000.000000
# 8126                 NaN                  1.0    5000.000000
# 13398                NaN                  NaN   10000.000000
# 15587                NaN                  NaN    4166.666667
#
# [6 rows x 137 columns]

# %% [markdown]
# There are 6 values in India over $2,000/month, which is an unusual amount to spend on education outside of University.  Participants of bootcamps could spend that much per month, but none of these survey takers participated in a bootcamp.  It is probably safe to remove these values.

# %%
# Drop India Outliers
top_4.drop(india_outliers.index, inplace=True)

# %%
money_country_new = top_4.groupby('CountryLive').mean()
money_country_new['MoneyPerMonth'][['United States of America',
                            'India', 'United Kingdom',
                            'Canada']]
# Out:
# CountryLive
# United States of America    197.936643
# India                        64.958227
# United Kingdom               49.117435
# Canada                      129.170946
# Name: MoneyPerMonth, dtype: float64

# %%
top_4['CountryLive'].value_counts(normalize=True)
# Out:
# United States of America    0.750298
# India                       0.115453
# United Kingdom              0.073687
# Canada                      0.060561
# Name: CountryLive, dtype: float64

# %% [markdown]
# The bulk of the advertising budget should go to the US, as individuals spend almost double of any other country,and has the highest participation.  The second country to advertise in should be India, as they are willing to pay at least the subscription cost and have double the potential subscribers.
