# %% [markdown]
# # Ebay Car Sales Data
#
# A dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website.
#
# The dataset was originally scraped and uploaded to Kaggle

# %%
# Setting up the environment

import re
import numpy as np
import pandas as pd

# Reading in the data

autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
# Previewing data

print(autos.info())
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# postalCode             50000 non-null int64
# lastSeen               50000 non-null object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB
# None
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %% [markdown]
# ## Column Observations
#
# Most of the columns were imported as object types, with the exception of:
# - year of registration
# - month of registration
# - number of pictures
# - postal code
#
# The number of data points scrapped was 50,000.  There are multiple columns that have less than 50,000 non-null values.
# - vehicle type
# - gearbox
# - model
# - fuel type
# - not repaired damage

# %%
# Examining column names
column_name = autos.columns

# %%
# Creating a function to clean column names
def clean_col_names(name_string):
    new_string = name_string[0].upper() + name_string[1:]
    name_list = re.findall('[A-Z][^A-Z]*', new_string)
    cleaned_list = [name_list[0].lower()]
    for word in name_list[1:]:
        cleaned_list.append("_" + word.lower())
    return "".join(cleaned_list)
    
# Applying the clean column function to the list of column names
new_col_name = [clean_col_names(x) for x in column_name]

# Getting the column names into a consistent format
autos.columns = new_col_name

# Reassigning confusing column names 
rename_dict = {
    'year_of_registration':'registration_year',
    'month_of_registration':'registration_month',
    "not_repaired_damage":'unrepaired_damage',
    'date_created':'ad_created'
}

autos = autos.rename(rename_dict, axis='columns')

# %% [markdown]
# Column names were renamed to provide a consistent syntax in order to reduce confusion and make the columns easier to work with.
#
# ## Exploring Data

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-23 19:38:20  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox     power_p_s  model  \
# count         44905       50000.000000    47320  50000.000000  47242
# unique            8                NaN        2           NaN    245
# top       limousine                NaN  manuell           NaN   golf
# freq          12859                NaN    36993           NaN   4024
# mean            NaN        2005.073280      NaN    116.355920    NaN
# std             NaN         105.712813      NaN    209.216627    NaN
# min             NaN        1000.000000      NaN      0.000000    NaN
# 25%             NaN        1999.000000      NaN     70.000000    NaN
# 50%             NaN        2003.000000      NaN    105.000000    NaN
# 75%             NaN        2008.000000      NaN    150.000000    NaN
# max             NaN        9999.000000      NaN  17700.000000    NaN
#
#          odometer  registration_month fuel_type       brand unrepaired_damage  \
# count       50000        50000.000000     45518       50000             40171
# unique         13                 NaN         7          40                 2
# top     150,000km                 NaN    benzin  volkswagen              nein
# freq        32424                 NaN     30107       10687             35232
# mean          NaN            5.723360       NaN         NaN               NaN
# std           NaN            3.711984       NaN         NaN               NaN
# min           NaN            0.000000       NaN         NaN               NaN
# 25%           NaN            3.000000       NaN         NaN               NaN
# 50%           NaN            6.000000       NaN         NaN               NaN
# 75%           NaN            9.000000       NaN         NaN               NaN
# max           NaN           12.000000       NaN         NaN               NaN
#
#                  ad_created  nr_of_pictures   postal_code            last_seen
# count                 50000         50000.0  50000.000000                50000
# unique                   76             NaN           NaN                39481
# top     2016-04-03 00:00:00             NaN           NaN  2016-04-07 06:17:27
# freq                   1946             NaN           NaN                    8
# mean                    NaN             0.0  50813.627300                  NaN
# std                     NaN             0.0  25779.747957                  NaN
# min                     NaN             0.0   1067.000000                  NaN
# 25%                     NaN             0.0  30451.000000                  NaN
# 50%                     NaN             0.0  49577.000000                  NaN
# 75%                     NaN             0.0  71540.000000                  NaN
# max                     NaN             0.0  99998.000000                  NaN

# %% [markdown]
# ## Data Cleaning
#
# - The seller column is almost entirely made up of the value "privat"
# - The offer_type column is also similarly consistent with the value "Angebot"
# - Columns that are object type that should be a numeric type:
#     - price
#     - odometer

# %%
# Looking at the price column 
autos['price'].unique()
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$385', '$22,200', '$16,995'],
#       dtype=object)

# %%
# Removing non-numeric characters
autos['price'] = (autos['price']
                      .str.replace("$", "")
                      .str.replace(",", "")
                      .astype(int)
                 )

# %%
# Looking at the odometer column
autos['odometer'].unique()
# Out:
# array(['150,000km', '70,000km', '50,000km', '80,000km', '10,000km',
#        '30,000km', '125,000km', '90,000km', '20,000km', '60,000km',
#        '5,000km', '100,000km', '40,000km'], dtype=object)

# %%
# Removing non-numeric characters 
autos['odometer'] = (autos['odometer']
                         .str.replace("km", "")
                         .str.replace(",", "")
                         .astype(int)
                    )

# %%
# Renaming column to capture lost data
autos = autos.rename({'odometer':'odometer_km'}, axis="columns")

# %%
# Checking work
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  power_p_s   model  odometer_km  registration_month fuel_type  \
# 0    manuell        158  andere       150000                   3       lpg
# 1  automatik        286     7er       150000                   6    benzin
# 2    manuell        102    golf        70000                   7    benzin
# 3  automatik         71  fortwo        70000                   6    benzin
# 4    manuell          0   focus       150000                   7    benzin
#
#         brand unrepaired_damage           ad_created  nr_of_pictures  \
# 0     peugeot              nein  2016-03-26 00:00:00               0
# 1         bmw              nein  2016-04-04 00:00:00               0
# 2  volkswagen              nein  2016-03-26 00:00:00               0
# 3       smart              nein  2016-03-12 00:00:00               0
# 4        ford              nein  2016-04-01 00:00:00               0
#
#    postal_code            last_seen
# 0        79588  2016-04-06 06:45:54
# 1        71034  2016-04-06 14:45:08
# 2        35394  2016-04-06 20:15:37
# 3        33729  2016-03-15 03:16:28
# 4        39218  2016-04-01 14:38:50

# %% [markdown]
# ## Descriptive Statistics: Odometer

# %%
# Looking at unique values
print(autos['odometer_km'].unique().shape)
# Looking at general statistics for the series
print(autos['odometer_km'].describe())
# Looking at the number of each of the values
print(autos['odometer_km'].value_counts().sort_index(ascending=False))
# Out:
# (13,)
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# 5000        967
# Name: odometer_km, dtype: int64

# %% [markdown]
# There does not appear to be any outliers in the odometer column.  All of the values are reasonable odometer readings for a car.
#
# ## Descriptive Statistcs: Price

# %%
# Looking at unique values
print(autos['price'].unique().shape)
# Looking at general statistics for the series
print(autos['price'].describe())
# Looking at the number of each of the values
print(autos['price'].value_counts().sort_index(ascending=False).head(20))
print(autos['price'].value_counts().sort_index(ascending=False).tail(20))
# Out:
# (2357,)
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# Name: price, dtype: int64
# 35       1
# 30       7
# 29       1
# 25       5
# 20       4
# 18       1
# 17       3
# 15       2
# 14       1
# 13       2
# 12       3
# 11       2
# 10       7
# 9        1
# 8        1
# 5        2
# 3        1
# 2        3
# 1      156
# 0     1421
# Name: price, dtype: int64

# %%
# Removing outliers
autos = autos[autos["price"].between(100,1000000)]

# %% [markdown]
# ## Dates

# %%
# Looking at the date values
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
# Getting just the date
autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).head(10)
# Out:
# 2016-04-03    0.038609
# 2016-03-20    0.037800
# 2016-03-21    0.037220
# 2016-03-12    0.036909
# 2016-03-14    0.036660
# 2016-04-04    0.036536
# 2016-03-07    0.036059
# 2016-04-02    0.035602
# 2016-03-28    0.034960
# 2016-03-19    0.034732
# Name: date_crawled, dtype: float64

# %%
autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).head(10)
# Out:
# 2016-04-03    0.038858
# 2016-03-20    0.037863
# 2016-03-21    0.037448
# 2016-04-04    0.036888
# 2016-03-12    0.036743
# 2016-03-14    0.035291
# 2016-04-02    0.035291
# 2016-03-28    0.035063
# 2016-03-07    0.034794
# 2016-03-29    0.034089
# Name: ad_created, dtype: float64

# %%
autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).head(10)
# Out:
# 2016-04-06    0.221971
# 2016-04-07    0.132146
# 2016-04-05    0.125054
# 2016-03-17    0.028096
# 2016-04-03    0.025131
# 2016-04-02    0.024882
# 2016-03-30    0.024696
# 2016-04-04    0.024530
# 2016-03-31    0.023825
# 2016-03-12    0.023783
# Name: last_seen, dtype: float64

# %% [markdown]
# Most of the crawling was done between March-April 2016, which corresponds similarly to the date the add was creaeted and the date "last seen."  Car sites tend to have a limited amount of time for a posting before it is automatically removed.

# %%
autos['registration_year'].describe()
# Out:
# count    48227.000000
# mean      2004.730151
# std         87.894768
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# One thing that stands out from the exploration is that the registration_year column contains some odd values:
#
#     The minimum value is 1000, before cars were invented
#     The maximum value is 9999, many years into the future

# %%
# Looking at irregular registration years
autos[~autos["registration_year"].between(1900,2016)]
# Out:
#               date_crawled                                               name  \
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 65     2016-04-04 19:30:39                      Ford_Fiesta_zum_ausschlachten
# 68     2016-04-03 17:36:59  Mini_cooper_s_clubman_/vollausstattung_/_Navi/...
# 84     2016-03-27 19:52:54                                     Renault_twingo
# 113    2016-04-03 14:58:29                              Golf_4_Anfaenger_auto
# 164    2016-03-13 20:39:16  Opel_Meriva__nur_76000_Km__unfallfrei__scheckh...
# 197    2016-04-05 10:36:24                              VW_Polo_9N_an_Bastler
# 253    2016-03-27 13:25:18             Ford_mondeo_Gas_anlage_mit_TÜV_04.2017
# 348    2016-03-17 20:58:24  VW_Beetle_1.8Turbo_mit_Vollausstattung_und_seh...
# 390    2016-03-25 12:59:06   Fiat_Bertone_X_1_9__X_1/9__X19__X_19__X1_9__X_19
# 438    2016-03-10 20:36:25                VW_Golf_5_V_1.6_2004_Klima_Tempomat
# 453    2016-03-28 13:51:12                                         Armee_Jeep
# 454    2016-03-25 09:57:03    Ford_Fiesta_Servo_D3_Kat_86_Steuern_65.000_tkm
# 457    2016-03-15 17:48:39  Mercedes_Benz_W203_C200_Kombi_Kompressor_c_kla...
# 477    2016-03-31 08:53:34                                         Citroën_C4
# 545    2016-03-22 18:50:53                                      Bmw_x5_/__E53
# 548    2016-03-10 17:44:57            Peugeot_206_1.9_Hdi_4_Tueren_Tuev_02.17
# 557    2016-03-16 03:36:34                           Smart_Fortwo_Passion_MHD
# 49796  2016-03-09 09:38:38                        Opel_corsa_1.4_zu_verkaufen
# 49841  2016-03-11 15:37:02                                  Passat_abzugeben.
# 49910  2016-04-03 21:39:15  Schoener_fast_neuer_Opel_Mokka_in_Zell_Mosel_m...
# 49935  2016-04-01 21:48:20  Mercedes_A_klasse_angemeldet_mit_Tuef_und_Auto...
#
#        seller offer_type  price   abtest vehicle_type  registration_year  \
# 10     privat    Angebot    999     test          NaN               2017
# 65     privat    Angebot    250  control          NaN               2017
# 68     privat    Angebot  10990     test          NaN               2017
# 84     privat    Angebot    900  control          NaN               2018
# 113    privat    Angebot   1200     test          NaN               2017
# 164    privat    Angebot   4800  control          NaN               2018
# 197    privat    Angebot    888  control          NaN               2017
# 253    privat    Angebot   2250     test          NaN               2017
# 348    privat    Angebot   3750  control          NaN               2017
# 390    privat    Angebot   7750     test          NaN               2018
# 438    privat    Angebot   4150     test          NaN               2017
# 453    privat    Angebot   9800     test          NaN               4500
# 454    privat    Angebot    750     test          NaN               2017
# 457    privat    Angebot   3000  control          NaN               2017
# 477    privat    Angebot   3200  control          NaN               2017
# 545    privat    Angebot   4300     test          NaN               2017
# 548    privat    Angebot   1399  control          NaN               2017
# 557    privat    Angebot   4900     test          NaN               2017
# 568    privat    Angebot   1950  control          NaN               2017
# 577    privat    Angebot    650     test          NaN               2017
# 582    privat    Angebot   7300  control          NaN               2017
# 654    privat    Angebot   2000     test          NaN               2017
# 740    privat    Angebot   2400  control          NaN               2017
# 754    privat    Angebot   1850  control          NaN               2017
# 758    privat    Angebot   1200     test          NaN               2017
# 765    privat    Angebot   1350  control          NaN               2017
# 802    privat    Angebot   2100     test          NaN               2018
# 871    privat    Angebot   1450     test          NaN               2017
# 889    privat    Angebot    870  control          NaN               2017
# 910    privat    Angebot   1500  control          NaN               2017
# ...       ...        ...    ...      ...          ...                ...
# 49130  privat    Angebot   2699     test          NaN               2017
# 49153  privat    Angebot   2500     test          NaN               5000
# 49154  privat    Angebot    400  control          NaN               2017
# 49178  privat    Angebot   1500  control          NaN               2018
# 49185  privat    Angebot   1200  control          NaN               2019
# 49218  privat    Angebot   2750  control          NaN               2018
# 49245  privat    Angebot   3300  control          NaN               2017
# 49259  privat    Angebot    999     test          NaN               2017
# 49261  privat    Angebot   2800     test          NaN               2017
# 49262  privat    Angebot   2000     test          NaN               2018
# 49266  privat    Angebot   7699  control          NaN               2017
# 49283  privat    Angebot   7750  control          NaN               1001
# 49343  privat    Angebot   4400     test          NaN               2017
# 49347  privat    Angebot    950  control          NaN               2017
# 49354  privat    Angebot   2499  control          NaN               2018
# 49389  privat    Angebot    950  control          NaN               2017
# 49411  privat    Angebot   1550     test          NaN               2018
# 49522  privat    Angebot    350  control          NaN               2017
# 49557  privat    Angebot   6250     test          NaN               2017
# 49561  privat    Angebot   6500     test          NaN               2017
# 49653  privat    Angebot   1050  control          NaN               2017
# 49662  privat    Angebot    333     test          NaN               2017
# 49689  privat    Angebot   4700  control          NaN               2017
# 49696  privat    Angebot   1250  control          NaN               2017
# 49731  privat    Angebot   1700     test          NaN               2017
# 49770  privat    Angebot    999  control          NaN               2018
# 49796  privat    Angebot   4500     test          NaN               2017
# 49841  privat    Angebot    600     test          NaN               2017
# 49910  privat    Angebot  22200     test          NaN               9000
# 49935  privat    Angebot    800     test          NaN               2017
#
#          gearbox  power_p_s     model  odometer_km  registration_month  \
# 10       manuell         90       NaN       150000                   4
# 65       manuell         65    fiesta       125000                   9
# 68       manuell        174   clubman       100000                   0
# 84           NaN         60    twingo       150000                   0
# 113      manuell         75      golf       150000                   7
# 164      manuell          0    meriva        80000                   4
# 197      manuell         64      polo        20000                   7
# 253      manuell          0    mondeo       150000                   8
# 348      manuell        150    beetle       150000                   7
# 390      manuell         76    andere       150000                   6
# 438      manuell        102      golf       150000                   0
# 453      manuell          0    andere         5000                   0
# 454      manuell         50    fiesta        70000                   0
# 457      manuell        163  c_klasse       150000                   8
# 477      manuell         88       NaN       125000                   2
# 545    automatik        184   x_reihe       150000                   7
# 548      manuell         90   2_reihe       150000                   6
# 557    automatik         71    fortwo        30000                   4
# 568    automatik         54    fortwo       125000                  12
# 577      manuell         75      golf       150000                   1
# 582    automatik        313   touareg       150000                   7
# 654      manuell          0     kalos       100000                   5
# 740      manuell        104      leon       150000                   2
# 754          NaN         60        ka       125000                   3
# 758          NaN         90     civic       150000                  12
# 765      manuell          0       3er       150000                   3
# 802      manuell          0    kalina       150000                   0
# 871      manuell         60        c2       150000                   3
# 889      manuell         75     corsa       150000                  10
# 910      manuell         75    kangoo       150000                   5
# ...          ...        ...       ...          ...                 ...
# 49130    manuell         75     modus       150000                   6
# 49153        NaN          0     corsa         5000                   0
# 49154    manuell         60     ibiza       150000                   7
# 49178    manuell         98   3_reihe       150000                   6
# 49185    manuell        140       156       150000                   5
# 49218    manuell         60    fiesta       125000                   4
# 49245    manuell        150        a3       150000                   4
# 49259    manuell         50      lupo       150000                   0
# 49261    manuell          0      aygo        90000                   6
# 49262        NaN          0       NaN       150000                   0
# 49266    manuell        177       NaN       125000                  12
# 49283        NaN          0    andere         5000                   0
# 49343    manuell          0       3er       150000                   0
# 49347    manuell         90     civic       150000                   0
# 49354    manuell        174       5er       150000                   8
# 49389        NaN          0     astra       150000                   0
# 49411        NaN          0    twingo       100000                   0
# 49522    manuell         72       NaN       150000                  12
# 49557  automatik        205  e_klasse       150000                   3
# 49561    manuell          0    galaxy       150000                   6
# 49653    manuell        110    scenic       150000                   8
# 49662    manuell          0     cuore       125000                   0
# 49689    manuell        105       NaN       150000                   0
# 49696    manuell        101        a3       150000                   8
# 49731    manuell          0    megane       150000                   7
# 49770    manuell         75      polo       150000                  12
# 49796    manuell         90     corsa        70000                   7
# 49841    manuell        101    passat       150000                   7
# 49910  automatik        140    andere        10000                   3
# 49935  automatik        101  a_klasse       150000                   9
#
#       fuel_type          brand unrepaired_damage           ad_created  \
# 10       benzin     volkswagen              nein  2016-03-14 00:00:00
# 49796               0        88433  2016-03-17 20:45:08
# 49841               0        53804  2016-03-11 16:41:14
# 49910               0        56856  2016-04-05 22:18:26
# 49935               0        39108  2016-04-01 21:48:20
#
# [1872 rows x 20 columns]

# %% [markdown]
# All of these have registration years that are before the time of cars or later than the date crawled, which is not very plausible.
#
# ## Brands

# %%
# Looking at the top 20 car brands
car_brands = autos['brand'].value_counts(normalize=True).index

# %%
brand_dict = {}
for car in car_brands:
    brand_subset = autos[autos["brand"]==car]
    brand_dict[car] = brand_subset['price'].mean()
    
brand_dict
# Out:
# {'alfa_romeo': 4054.471875,
#  'audi': 9259.510248372317,
#  'bmw': 8310.138470341408,
#  'chevrolet': 6692.60294117647,
#  'chrysler': 3539.9166666666665,
#  'citroen': 3783.6788856304984,
#  'dacia': 5897.736434108527,
#  'daewoo': 1093.6,
#  'daihatsu': 1641.2644628099174,
#  'fiat': 2815.635782747604,
#  'ford': 4053.7575215966635,
#  'honda': 4010.4728682170544,
#  'hyundai': 5416.23382045929,
#  'jaguar': 11844.041666666666,
#  'jeep': 11573.638888888889,
#  'kia': 5923.288629737609,
#  'lada': 2647.7241379310344,
#  'lancia': 3240.703703703704,
#  'land_rover': 18934.272727272728,
#  'mazda': 4075.319293478261,
#  'mercedes_benz': 8580.202247191011,
#  'mini': 10566.824940047962,
#  'mitsubishi': 3414.741116751269,
#  'nissan': 4681.94046008119,
#  'opel': 2974.764503159104,
#  'peugeot': 3086.930281690141,
#  'porsche': 46764.2,
#  'renault': 2450.9015611448394,
#  'rover': 1586.4923076923078,
#  'saab': 3183.493670886076,
#  'seat': 4348.652792990142,
#  'skoda': 6394.309677419355,
#  'smart': 3538.344927536232,
#  'sonstige_autos': 12575.773626373626,
#  'subaru': 4068.3861386138615,
#  'suzuki': 4166.767605633803,
#  'toyota': 5148.0032733224225,
#  'trabant': 1823.030303030303,
#  'volkswagen': 5559.672052954346,
#  'volvo': 4911.680459770115}

# %% [markdown]
# The most expensive cars are brands most often associated with sports cars. Cheaper cars consist primarily of French cars and old Soviet cars.

# %%
# Looking at odometer readings compared to price
top_5_car_brands = autos['brand'].value_counts(normalize=True).head(5).index
brand_dict_price = {}
brand_dict_mileage = {}
for car in top_5_car_brands:
    brand_subset = autos[autos["brand"]==car]
    brand_dict_price[car] = brand_subset['price'].mean()
    brand_dict_mileage[car] = brand_subset['odometer_km'].mean()

# %%
# Creating a dataframe from the dictionaries
top_5_price = pd.Series(brand_dict_price)
top_5_mileage = pd.Series(brand_dict_mileage)

top_5_df = pd.DataFrame(top_5_price, columns=['mean_price'])
top_5_df['mean_mileage'] = top_5_mileage

# %%
top_5_df
# Out:
#                 mean_price   mean_mileage
# audi           9259.510248  129604.533398
# bmw            8310.138470  132824.718673
# mercedes_benz  8580.202247  131027.441659
# opel           2974.764503  129442.848937
# volkswagen     5559.672053  129012.946559

# %% [markdown]
# Price and high odometer reading do not appear to be directly correlated.  Opel vehicles are relatively cheap and the mileage difference between Audi and BMW is small.  This could be due to ease of repairability.
